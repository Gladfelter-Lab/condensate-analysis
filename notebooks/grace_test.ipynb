# %%
import sys
sys.path.insert(1, '../src')
import condensate_analysis as ca
import matplotlib.pyplot as plt
import numpy as np

# %%
img = ca.read_image("../test_data/F16_1257_20r_4p_.nd2")
print(img.shape)
# Out:
# (2, 21, 2048, 2048)

# %%
plt.imshow(img[1,10])

# %%
mask, rgb_mask = ca.mask_image(img[1,10], stack=False, watershed=False)

# %%
plt.imshow(rgb_mask)
